# %% [markdown]
# # String Manipulation in Python
#
# A string is a list of characters in order.
#
# A character is anything you can type on the keyboard in one keystroke,
# like a letter, a number, or a backslash.
#
# Strings can have spaces: "hello world".
#
# An empty string is a string that has 0 characters.
#
# Python strings are immutable
#
# Python recognize as strings everything that is delimited by quotation marks
# (" " or ' ').

# %% [markdown]
# ## String Manipulation
# To manipulate strings, we can use some of Pythons built-in methods.

# %% [markdown]
# ### Creation

# %%
word = "Hello World"
print(word)
# Out:
# Hello World

# %% [markdown]
# ### Accessing
# Use [ ] to access characters in a string

# %%
word = "Hello World"
letter = word[0]
print(letter)
# Out:
# H

# %% [markdown]
# ### Length

# %%
word = "Hello World"
len(word)
# Out:
# 11

# %% [markdown]
# ### Finding

# %%
word = "Hello World"

print(word.count('l')) # count how many times l is in the string: string.count(substring, start=..., end=...) -< #
print(word.find("l")) # find the word H in the string: str.find(sub[, start[, end]] ) -< -1 / index, rfind start search right first
print(word.index("World"))# find the letters World in the string, ==
# Out:
# 3
# 2
# 6

# %% [markdown]
# ### Count

# %%
s =  "Count, the number     of spaces"
print(s.count(' '))
# Out:
# 8

# %% [markdown]
# ### Slicing
# Use [ # : # ] to get set of letter
#
# Keep in mind that python, as many other languages, starts to count from 0!!

# %%
word = "Hello World"

print(word[0])          #get one char of the word
print(word[0:1])        #get one char of the word (same as above)
print(word[0:3])        #get the first three char
print(word[:3])         #get the first three char
print(word[-3:])        #get the last three char
print(word[3:])         #get all but the three first char
print(word[:-3])        #get all but the three last character
print(word[::2])        #Skipping letters with a step of 2
# Out:
# H
# H
# Hel
# Hel
# rld
# lo World
# Hello Wo
# HloWrd

# %%
# To reverse a string using the slice syntax
my_string = "ferrari"
my_string_reversed = my_string[::-1]
print(my_string_reversed)
# Out:
# irarref

# %% [markdown]
# ### Split Strings

# %%
word = "Hello World"
word.split(' ')  # Split on whitespace
# Out:
# ['Hello', 'World']

# %% [markdown]
# ### Startswith / Endswith

# %%
word = "hello world"
print(word.startswith("H"))
print(word.endswith("d"))
print(word.endswith("w"))
# Out:
# False
# True
# False

# %% [markdown]
# ### Repeat Strings

# %%
print("."* 10) # prints ten dots
# Out:
# ..........

# %% [markdown]
# ### Replacing

# %%
word = "Hello World"
word.replace("Hello", "Goodbye")
# Out:
# 'Goodbye World'

# %% [markdown]
# ### Changing Upper and Lower Case Strings

# %%
string = "Hello World"
print(string.upper())
print(string.lower())
print(string.title())
print(string.capitalize())
print(string.swapcase())
# Out:
# HELLO WORLD
# hello world
# Hello World
# Hello world
# hELLO wORLD

# %% [markdown]
# ### Strip off newline characters from end of the string
# strip()     #removes from both ends
# lstrip()    #removes leading characters (Left-strip)
# rstrip()    #removes trailing characters (Right-strip)

# %%
word = "    xyz    "
print(word)
print(word.strip())
print(word.lstrip())
print(word.rstrip())
# Out:
#     xyz
# xyz
# xyz
#     xyz

# %%
regular_text = ",This is a regular text.,$@G#,"

clean_end_text = regular_text.rstrip(",")

print(regular_text)
print(clean_end_text)
# Out:
# ,This is a regular text.,$@G#,
# ,This is a regular text.,$@G#

# %%
regular_text = "AbC#This is a regular text.$@G#"

clean_text = regular_text.strip("AbC#$@G")

print(regular_text)
print(clean_text)
# Out:
# AbC#This is a regular text.$@G#
# This is a regular text.

# %%
regular_text = "AbC#This is a regular text.$@G#"

clean_text = regular_text.strip("bAC#$@G")

print(regular_text)
print(clean_text)
# Out:
# AbC#This is a regular text.$@G#
# This is a regular text.

# %% [markdown]
# ### Concatenation
# To concatenate strings in Python use the "+" operator.

# %%
print("Hello " + "World")
print("Hello " + "World" + "!")
# Out:
# Hello World
# Hello World!

# %% [markdown]
# ### Join
# The join() method provides a flexible way to concatenate string. It concatenates each element of an iterable (such as list, string and tuple) to the string and returns the concatenated string.
#
# The syntax of join() is:
#
# string.join(iterable)

# %%
word = "hello word"
print(":".join(word))  # #add a : between every char
# Out:
# h:e:l:l:o: :w:o:r:d

# %%
numList = ['1', '2', '3', '4']
seperator = ', '
print(seperator.join(numList))
print(type(seperator.join(numList)))
# Out:
# 1, 2, 3, 4
# <class 'str'>

# %%
sentence = ["this", "is", "the", "best", "class", "ever"]
" ".join(sentence)
# Out:
# 'this is the best class ever'

# %% [markdown]
# ### Center

# %%
word = 'beach'
number_spaces = 32

word_centered = word.center(number_spaces)

print(word)
print('/'+word_centered+'/', len(word_centered))
# Out:
# beach
# /             beach              / 32

# %%
word = 'beach'
number_chars = 33
char = '$'

word_centered = word.center(number_chars, char)

print(word)
print(word_centered)
# Out:
# beach
# $$$$$$$$$$$$$$beach$$$$$$$$$$$$$$

# %% [markdown]
# ### Testing
# A string in Python can be tested for truth value.
#
# The return type will be in Boolean value (True or False)

# %%
word = "Hello World"

print('1-',word.isalnum())         #check if all char are alphanumeric
print('2-',word.isalpha())         #check if all char in the string are alphabetic
print('3-',word.isdigit())         #test if string contains digits
print('4-',word.istitle())         #test if string contains title words
print('5-',word.isupper())         #test if string contains upper case
print('6-',word.islower())         #test if string contains lower case
print('7-',word.isspace())         #check if all char are spaces
print('8-',word.endswith('d'))     #test if string endswith a d
print('10-',word.startswith('H'))   #test if string startswith H
# Out:
# 1- False
# 2- False
# 3- False
# 4- True
# 5- False
# 6- False
# 7- False
# 8- True
# 10- True

# %%
#The pythonic way to check if a string is empty is using the not operator.

my_string = ''
if not my_string:
  print("My string is empty!!!")
# Out:
# My string is empty!!!

# %% [markdown]
# ### Triple Quotes and Long String
# To handle multiline strings in Python you use triple quotes, either single or double.

# %%
long_text = """This is a multiline,

a long string with lots of text,

I'm wrapping it in triple quotes to make it work."""

print(long_text)
# Out:
# This is a multiline,
#
# a long string with lots of text,
#
# I'm wrapping it in triple quotes to make it work.

# %%
long_text = "This is a multiline, \n\n" \
"a long string with lots of text \n\n" \
"I'm using backlashes to make it work."
print(long_text)
# Out:
# This is a multiline,
#
# a long string with lots of text
#
# I'm using backlashes to make it work.

# %% [markdown]
# There are more ...
#
# https://www.w3schools.com/python/python_ref_string.asp
